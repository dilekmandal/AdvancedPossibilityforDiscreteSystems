# %% [markdown]
# <a href="https://colab.research.google.com/github/dilekmandal/Ayrik_Sistemler_icin_Ileri_Olasilik/blob/main/Kesikli_Olasilik_Fonksiyonu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Kesikli Olasılık Fonksiyonu
# **Rasgele Değişken:** Bir örnek uzaydaki her rasgele olaya sayısal bir değer atayan bir
# fonksiyondur. Başka bir ifadeyle rastgele değişken fonksiyonu, örnek uzayı ile reel sayılar kümesi
# arasında bir bağıntı kurar. Rastgele değişken
# X Y Z , , … ile, aldığı değerler ise
# x y z , , … gibi simgelerle
# gösterilir. Rasgele değişkenler kesikli rasgele değişken ve sürekli rasgele değişken olmak üzere
# ikiye ayrılır.
#
# **Kesikli Rastgele Değişken:**
# X
# rastgele değişkeninin aldığı değerlerin kümesi sonlu yada sayılabilir sonsuzlukta ise
# X
# ’e
# “kesikli rastgele değişken” denir.
# Örneğin: kız çocuk sayısı, öğrenci sayısı, sınıf sayısı
#
# **Sürekli Rastgele Değişken:** Eğer
# X
# rastgele değişkenin tanım bölgesi bir aralık ya da aralıklar kümesi ise
# X
# ’e “sürekli
# rastgele değişken” denir.
# Örneğin: araba hızı, yağış miktarı, kan basıncı
#
# ![resim.PNG](data:image/png;base64,...)

# %% [markdown]
# **SORU:**
#
# Bir balıkçının bir günde tuttuğu ortalama balık miktarını gösteren X rastgele değişkeninin olasılık fonksiyonu,![kesikli olasılık.PNG](data:image/png;base64,...)
#
# şeklinde olsun.
#
# a) Balıkçının tam 8 balık tutma olasılığını hesaplayın.
#
# b) Balıkçının 8'den az balık tutma olasılığını hesaplayınız.
#
# c)Balıkçının 8'den çok balık tutma olasılığını hesaplayınız.
#
# d)Balıkçının 6 ile 18 arasında balık tutma olasılığını hesaplayınız.
#
#
# **ÇÖZÜM:**
#
# Verilen olasılık fonksiyondan yola çıkıp işlemlerimizi gerçekleştiriyoruz.
#
# a) Verilen olasılık fonksiyonuna göre rastgele değişkenin(X) 1-10 arasındaki değerini bulurken kullanacağımız fonksiyon ![x.PNG](data:image/png;base64,...) fonksiyonudur. Buna göre:
#
# ![1.png](data:image/png;base64,...)
#
# b) Balıkçının 8'den az balık tutması demek, rastgele değişkenin değerinin 1 den 7'ye kadar olan olasılık değerlerinin toplamı demektir.
#
# ![2.png](data:image/png;base64,...)
#
# c) Balıkçının 8'den çok balık tutma olasılığını hesaplarken olasılık fonksiyonundaki 8'den büyük olan en byük değere kadar olan değerleri hesaplayacağz.
#
# ![4.png](data:image/png;base64,...)
#
# d)X rastgele değişkeninin olasılık fonksiyonundaki 6-18 aralığına karşılık gelen değerleri hesaplayacağız.
# ![5.png](data:image/png;base64,...)
#
# ![6.PNG](data:image/png;base64,...)

# %%
def kesikli_olasilik_fonksiyonu(x):
  if x>= 1 and x<=10:
    return x*(1/100)      
  elif x>= 11 and x<=20:
    return (20-x)*(1/100)

print("a) Balıkçının tam 8 balık tutma olasılığını hesaplayın.")
print("Balıkçının tam 8 balık tutma ihtimali = P(8) :",kesikli_olasilik_fonksiyonu(8))
print("\n")


print("b) Balıkçının 8'den az balık tutma olasılığını hesaplayınız")

sekizden_az_balik = 0
i = 0
while i < 7:
  i += 1
  
  print("Balıkçının",i," balık tutma ihtimali = P(",i,"): ",kesikli_olasilik_fonksiyonu(i))
  sekizden_az_balik += kesikli_olasilik_fonksiyonu(i)
print("\n")
print("Balıkçının 8'den az balık  tutma ihtimali : ",sekizden_az_balik)



print("\n")
print("c) Balıkçının 8'den çok balık tutma olasılığını hesaplayınız")

sekizden_cok_balik = 0
i = 8
while i < 20:
  i += 1
  
  print("Balıkçının",i," balık tutma ihtimali = P(",i,"): ",kesikli_olasilik_fonksiyonu(i))

  sekizden_cok_balik += kesikli_olasilik_fonksiyonu(i)

print("\n")
print("Balıkçının 8'den cok balık  tutma ihtimali : ",sekizden_cok_balik)


print("\n")
print("d) Balıkçının 6 ile 18 arasında balık tutma olasılığını hesaplayınız")

total = 0
i = 5
while i < 18:
  i += 1
  
  print("Balıkçının",i," balık tutma ihtimali = P(",i,"): ",kesikli_olasilik_fonksiyonu(i))
  total += kesikli_olasilik_fonksiyonu(i)
print("\n")
print("Balıkçının 6 ile 18 arasında balık  tutma ihtimali : ",total)
# Out:
# a) Balıkçının tam 8 balık tutma olasılığını hesaplayın.
# Balıkçının tam 8 balık tutma ihtimali = P(8) : 0.08
#
#
# b) Balıkçının 8'den az balık tutma olasılığını hesaplayınız
# Balıkçının 1  balık tutma ihtimali = P( 1 ):  0.01
# Balıkçının 2  balık tutma ihtimali = P( 2 ):  0.02
# Balıkçının 3  balık tutma ihtimali = P( 3 ):  0.03
# Balıkçının 4  balık tutma ihtimali = P( 4 ):  0.04
# Balıkçının 5  balık tutma ihtimali = P( 5 ):  0.05
# Balıkçının 6  balık tutma ihtimali = P( 6 ):  0.06
# Balıkçının 7  balık tutma ihtimali = P( 7 ):  0.07
#
#
# Balıkçının 8'den az balık  tutma ihtimali :  0.28
#
#
# c) Balıkçının 8'den çok balık tutma olasılığını hesaplayınız
# Balıkçının 9  balık tutma ihtimali = P( 9 ):  0.09
# Balıkçının 10  balık tutma ihtimali = P( 10 ):  0.1
# Balıkçının 11  balık tutma ihtimali = P( 11 ):  0.09
# Balıkçının 12  balık tutma ihtimali = P( 12 ):  0.08
# Balıkçının 13  balık tutma ihtimali = P( 13 ):  0.07
# Balıkçının 14  balık tutma ihtimali = P( 14 ):  0.06
# ...
