# %% [markdown]
# <a href="https://colab.research.google.com/github/dilekmandal/Ayrik_Sistemler_icin_Ileri_Olasilik/blob/main/Ko%C5%9Fullu_Olas%C4%B1l%C4%B1k_%26_Bayes_Teoremi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **KOŞULLU OLASILIK**
#
# A ile B, E örnek uzayının iki olayı olsun. B olayının gerçekleşmiş olması koşuluyla A olayının olasılığına, A olayının B koşullu olasılığı denir. Koşullu olasılık P(A | B) ile sembolize edilir. Bu da:
#
#
# ![image.png](data:image/png;base64,...)
#
# A olayının B koşullu olasılığı, P(A  | B) ile gösterilir. Koşullu olasılık formülü olarak yukarıdaki eşitlikleri kullanabiliriz.
#
# Koşullu olasılıkta bilinen durum evrensel küme olur. İstenen durumda bilinen küme içinden alınır. Yani:
#
# ![image.png](data:image/png;base64,...)
#
# Örnek: Aşağıdaki evrensel kümeyi inceleyelim. Diyelim ki seçilen elemanın B kümesinde olduğu biliniyor. A∩B kümesinden  seçilme olasılığını hesaplayalım.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **PROBLEM:** Bir okulun öğrencilerinden %45’i fizik, %35’i matematik derslerinden ve %25’i hem fizik hem de matematik derslerinden başarısızdır. Rasgele seçilen bir öğrencinin,
#
# a) Fizikten başarısız olduğu biliniyorsa, matematikten de başarısız olma olasılığını bulunuz
#
# b)Matematikten başarısız olduğu biliniyor ise, fizikten de başarısız olma olasılığını bulunuz
#
# **ÇÖZÜM:**
#
# ![image.png](data:image/png;base64,...)

# %%
from math import factorial
from fractions import Fraction
import numpy as np
import random


print("Fizik dersinden başarısız olanların oranını girin: ")
pF = float(input("P(F): "))
print("Matematik dersinden başarısız olanların oranını girin:")
pM = float(input("P(M): "))
print("Her ikisinden de başarısız olanların oranını girin:")
pFnM = float(input("P(F n M): "))

pFM = pFnM / pM
pMF = pFnM / pF

print("Fizik dersinden başarısız olanların Matematik dersinden de başarısız olma olasılığı => p(F|M) :", pFM)
print("Matematik dersinden başarısız olanların Fizik dersinden de başarısız olma olasılığı => p(M|F) :", pMF)
# Out:
# Fizik dersinden başarısız olanların oranını girin:
# P(F): 0.45
# Matematik dersinden başarısız olanların oranını girin:
# P(M): 0.35
# Her ikisinden de başarısız olanların oranını girin:
# P(F n M): 0.25
# Fizik dersinden başarısız olanların Matematik dersinden de başarısız olma olasılığı => p(F|M) : 0.7142857142857143
# Matematik dersinden başarısız olanların Fizik dersinden de başarısız olma olasılığı => p(M|F) : 0.5555555555555556

# %% [markdown]
# **BAYES TEOREMİ**
#
# P(A|B) = B olayı gerçekleştiğinde A olayının gerçekleşme olasılığı
#
# P(A) = A olayının gerçekleşme olasılığı
#
# P(B|A) = A olayı gerçekleştiğinde B olayının gerçekleşme olasılığı
#
# P(B) = B olayının gerçekleşme olasılığı
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **SORU:**
#
#  Ayşe’nin matematik dersinden başarılı olma olasılığı 0. 80’dir. Arkadaşı Beyhan ise Ayşe’nin sınav sonuçları hakkında tahminlerde bulunmaktadır. Ancak, Ayşe başarılı iken, Beyhan’ın doğru tahminde bulunma olasılığı 0. 70, başarısız iken doğru tahminde bulunma olasılığı 0. 90’dır. Buna göre yarınki sınav için Beyhan Ayşe’nin başarısız olacağını söylediğine göre, Ayşe’nin başarılı olma olasılığı nedir?
#
# **ÇÖZÜM: **
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **SORU:**
#
# Bir araştırmaya göre her 43 çocuktan 1 tanesi, yetişkinlikte ortaya çıkan belli bir hastalığa yakalanmakta ve tam güvenilir olmamasına rağmen yapılan test sonuçlarına göre, hastalıklı bir çocuğun testi %80 pozitif, sağlıklı bir çocuğun testi ise %10 pozitif sonuç vermektedir. Bu bilgilere göre test sonucu pozitif olan bir çocuğun gerçekten hasta olma olasılığı nedir?
#
# **ÇÖZÜM:**
#
# P(A) : Çocuğun hasta olması olasılığı = 1/43
#
# P(B) : Testin pozitif çıkması olasılığı = 1/43 * 0.80 + 42/43 * 0.10 = 5/43
#
# P(A|B) : Pozitif çıkan testin hastalık çıkma olasılığı ( sorulan bu )
#
# P(B|A) : Hastalıklı çocuğun testinin pozitif çıkma olasılığı = 0.80
#
# P(A|B)=P(B|A)*P(A)/P(B) => (0.80 * 1/43) / (5/43) = 0.16 = %16 bulunur.
